# %% [markdown]
# # ML-04 — Search Intelligence Data Contract
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Aadirwt/Internship/blob/main/work/notebooks/w03_data_contract.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Unit of analysis + time window
#
# *One row = one what, over which dates? State it, then verify it below.*

# %% [markdown]
# ### Unit of Analysis
#
# One row represents one webpage (content page) with its SEO metrics for a specific month.
#
# ### Time Window
#
# I will use March 2026 (month = 2026-03). This historical month allows feature creation without using future information, helping prevent data leakage.

# %%
print("Unit of Analysis: One webpage per month")
print("Time Window: 2026-03")
# Out:
# Unit of Analysis: One webpage per month
# Time Window: 2026-03

# %% [markdown]
# ## 2. Fields: feature / label / context / excluded
#
# *Sort every field you plan to touch into these four buckets. Excluded needs a why.*

# %% [markdown]
# ### Features
# - search_volume
# - competition
# - ctr
# - avg_position
# - impressions
# - engagement_rate
#
# ### Label
# Content Priority Score
#
# ### Context
# - content_type
# - main_intent
# - client_id
#
# ### Excluded
# Future labels or columns derived from future data because they would introduce data leakage.

# %%
features = [
    "search_volume",
    "competition",
    "ctr",
    "avg_position",
    "impressions",
    "engagement_rate"
]

label = "content_priority"

context = [
    "content_type",
    "main_intent",
    "client_id"
]

excluded = [
    "future_label"
]

print("Features:", features)
print("Label:", label)
print("Context:", context)
print("Excluded:", excluded)
# Out:
# Features: ['search_volume', 'competition', 'ctr', 'avg_position', 'impressions', 'engagement_rate']
# Label: content_priority
# Context: ['content_type', 'main_intent', 'client_id']
# Excluded: ['future_label']

# %%
import os

for root, dirs, files in os.walk("/content"):
    for file in files:
        if file.endswith(".csv"):
            print(os.path.join(root, file))
# Out:
# /content/Internship/outputs/refresh_queue_sample.csv
# /content/Internship/data/raw/content_refresh_anonymized.csv
# /content/sample_data/california_housing_train.csv
# /content/sample_data/mnist_train_small.csv
# /content/sample_data/mnist_test.csv
# /content/sample_data/california_housing_test.csv

# %%
# !git clone https://github.com/Aadirwt/Internship.git
# Out:
# fatal: destination path 'Internship' already exists and is not an empty directory.

# %%
import os

for root, dirs, files in os.walk("/content/Internship"):
    for file in files:
        if file.endswith(".csv"):
            print(os.path.join(root, file))
# Out:
# /content/Internship/outputs/refresh_queue_sample.csv
# /content/Internship/data/raw/content_refresh_anonymized.csv

# %% [markdown]
# ## 3. Verify it with queries (grain, counts, missing values, windows)
#
# *Every claim above gets a query cell here. A contract claim without a query next to it is a guess.*

# %% [markdown]
# Three verification checks will be used:
#
# 1. Verify the number of rows.
# 2. Verify the selected month.
# 3. Check for missing values in important features.

# %%
import pandas as pd

df = pd.read_csv("/content/Internship/data/raw/content_refresh_anonymized.csv")

print("Rows:", len(df))

print("\nMissing Values")
print(df[
    [
        "search_volume",
        "competition",
        "ctr",
        "avg_position",
        "engagement_rate"
    ]
].isnull().sum())

print("\nColumns")
print(df.columns.tolist())
# Out:
# Rows: 30000
#
# Missing Values
# search_volume      2468
# competition        2468
# ctr                   0
# avg_position          0
# engagement_rate       0
# dtype: int64
#
# Columns
# ['content_id', 'client_id', 'search_volume', 'competition', 'competition_level', 'cpc', 'content_type', 'main_intent', 'word_count', 'char_count', 'provider_used', 'model_used', 'impressions_90d', 'clicks_90d', 'pageviews_90d', 'sessions_90d', 'users_90d', 'engaged_sessions_90d', 'ai_sessions_90d', 'scroll_events_90d', 'days_with_impressions', 'days_with_sessions', 'impressions_last_30d', 'clicks_last_30d', 'sessions_last_30d', 'impressions_prev_30d', 'clicks_prev_30d', 'sessions_prev_30d', 'content_age_days', 'age_tier', 'age_tier_order', 'days_since_last_update', 'freshness_tier', 'word_count_tier', 'char_count_tier', 'ctr', 'avg_position', 'engagement_rate', 'scroll_rate', 'ai_traffic_pct', 'impression_tier', 'position_tier', 'trend_direction', 'trend_pct']

# %% [markdown]
# ## 4. Data limits
#
# *What can this data never tell you? Unbalanced history, GSC-only early rows, window overlaps.*

# %% [markdown]
# ### Data Limitations
#
# The dataset contains historical SEO information only. It cannot predict future search engine algorithm changes, sudden market trends, or unexpected user behavior. Therefore, the results should be used for decision support rather than guaranteeing future performance.

# %%
print("Data limitation acknowledged.")
# Out:
# Data limitation acknowledged.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
