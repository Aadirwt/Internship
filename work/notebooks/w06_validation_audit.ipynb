# %% [markdown]
# # ML-09 — Validation and Research Claim Audit
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Aadirwt/Internship/blob/main/work/notebooks/w06_validation_audit.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Two paper findings + my methodology questions
#
# *Pick two findings from the FlyRank research paper. For each: where does the label come from, and does the validation design carry the claim? Constructive tone.*

# %% [markdown]
# ## Finding 1
#
# **Finding:**
# The FlyRank research paper found that refreshing older content significantly improves SEO performance. Updated pages showed higher content health scores and increased search impressions compared to pages that were not refreshed.
#
# **Methodology Question:**
# How were the refreshed pages selected, and were they compared over the same time period to ensure that the improvement was caused by the content update rather than seasonal or external factors?
#
# ---
#
# ## Finding 2
#
# **Finding:**
# The paper suggests that webpages ranking on the first page of search results or in the "striking distance" range provide strong opportunities for improving click-through rate through SEO optimization.
#
# **Methodology Question:**
# Was this finding validated across multiple websites and industries, or was it mainly influenced by a small number of clients with similar content?

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. My model under an honest split (before/after)
#
# *Re-run your Week-5 model under a grouped or time-aware split. Show both numbers.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Leakage audit
#
# *The same hunt from Week 3, on your final feature set.*

# %% [markdown]
# The final feature set was reviewed for possible data leakage.
#
# The model only uses historical SEO metrics such as search volume, competition, impressions, CTR, average position, engagement rate, and trend direction. No future information, manually assigned labels, or features generated after the prediction point were included in the model.
#
# Feature preparation is performed after the data split to reduce train-test contamination. Based on this review, no significant evidence of target leakage was observed.
#
# The feature set is therefore considered appropriate for prediction using only information available at the decision time.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. Claim rewrite
#
# *Take your own boldest sentence and rewrite it in safe language: observed, measured, directional, decision-support.*

# %% [markdown]
# Original Claim:
#
# "The model accurately identifies the webpages that should be optimized."
#
# Rewritten Claim:
#
# "The model provides a data-driven ranking of webpages based on historical SEO metrics. The results should be used as decision support for identifying optimization opportunities rather than as guaranteed predictions of future performance."

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
