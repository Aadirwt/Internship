# %% [markdown]
# # ML-09 — Validation and Research Claim Audit
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Aadirwt/Internship/blob/main/work/notebooks/w06_validation_audit.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Two paper findings + my methodology questions
#
# *Pick two findings from the FlyRank research paper. For each: where does the label come from, and does the validation design carry the claim? Constructive tone.*

# %% [markdown]
# Finding 1
# The FlyRank paper found that pages with stronger SEO signals such as higher search volume, better CTR, and stronger engagement generally performed better in content prioritization.
# Methodology Question:
# How were the target labels for high-priority content created? Were they generated from real business outcomes or from manually defined rules? Understanding the label source is important because it affects whether the model learns real user behavior or only predefined patterns.
#
#
# Finding 2
# The paper reported that machine learning models improved content prioritization compared to simple rule-based methods.
# Methodology Question:
# Was the validation performed using an honest split such as GroupKFold or a time-aware split to prevent information leakage? If training and testing data contain similar client records, the reported performance may be higher than what would be achieved on unseen data.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# Our original Week 5 model used a standard train-test split and achieved an accuracy of 1.00.
# For Week 6, the model was evaluated again using GroupKFold, grouping records by client to create a more realistic validation split.
#
# Validation Method	Accuracy
#
# Train-Test Split	1.00
#
# GroupKFold Split	1.00
#
#
# Although the accuracy remained unchanged, this does not necessarily prove that the model will generalize perfectly. The target labels in this project are created directly from the same SEO features used for training, making the prediction task relatively simple. The result should therefore be interpreted carefully rather than as evidence of perfect real-world performance.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Leakage audit
#
# *The same hunt from Week 3, on your final feature set.*

# %% [markdown]
# The dataset was checked for possible data leakage.
# Potential leakage points reviewed:
# Features used to generate the target label were examined.
# Client information was separated using GroupKFold to reduce overlap between training and testing data.
# No future information was intentionally included during prediction.
# The model still achieved perfect accuracy because the target variable is generated from existing SEO metrics such as search volume, CTR, and average position. This means the model is largely learning the rule used to create the labels rather than discovering hidden relationships.
# No additional evidence of train-test contamination was observed, but the label generation process should be considered when interpreting the results.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. Claim rewrite
#
# *Take your own boldest sentence and rewrite it in safe language: observed, measured, directional, decision-support.*

# %% [markdown]
# Original claim
# The Decision Tree model predicts content priority with perfect accuracy.
#
# Rewritten claim
#  Using the current dataset and evaluation procedure, the Decision Tree model achieved 1.00 accuracy under both the train-test split and the GroupKFold validation. This result was observed on this dataset. Because the target labels were generated from the same SEO features used for training, the result should be interpreted as evidence that the model successfully learned the defined rules rather than as proof of perfect performance on unseen real-world data.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
